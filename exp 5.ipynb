# %%
#to get 3rd element and last 3rd element
t=(10,20,30,40,50,60)
print("3rd element:",t[2])
print("3rd element form last:",t[-3])
# Out:
# 3rd element: 30
# 3rd element form last: 40

# %%
#average
number=input("enter the number:")
tuples=tuple(map(int,number.split(",")))
print("tuple is:",tuples)
print("average is:",sum(tuples)/len(tuples))
# Out:
# enter the number: 1 2 3 4 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 #average
#       2 number=input("enter the number:")
# ----> 3 tuples=tuple(map(int,number.split(",")))
#       4 print("tuple is:",tuples)
#       5 print("average is:",sum(tuples)/len(tuples))
#
# ValueError: invalid literal for int() with base 10: '1 2 3 4 5'
